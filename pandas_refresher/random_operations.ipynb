# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("housing_price.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
corr=df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\akr80\AppData\Local\Temp\ipykernel_15592\1885801018.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
# <style type="text/css">
# ...

# %%
df.describe(include='all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
numeric_types = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_data = df.select_dtypes(exclude='object')
numeric_data.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
columns_with_missing = numeric_data.columns[numeric_data.isna().any()]
columns_with_missing
# Out:
# Index([], dtype='object')

# %%
numeric_data1=numeric_data

# %%
#Handling missing values
numeric_data= numeric_data.apply(lambda x: x.fillna(x.mean()),axis = 0)

# %%
from sklearn.decomposition import PCA
pca_data = PCA(n_components=20)

# %%
pca_transformed_data = pca_data.fit_transform(numeric_data)

# %%
pca_df = pd.DataFrame(pca_transformed_data)
pca_df.head()
# Out:
#              0            1           2           3           4           5   \
# 0  27493.526046 -2993.925693 -296.465564  734.036092 -135.679227 -236.248832
# 1    547.725353  -929.990539  742.680275  242.243234  -30.971460 -267.736053
# 2  42579.462261  -701.927136 -477.038683  418.127971 -106.840663 -335.701437
# 3 -40929.737428   409.250676 -574.720156  102.288078  -69.322672  -18.371284
# 4  69169.765847  1418.332050 -521.346609  376.755964  -93.305112   27.671140
#
#            6           7           8           9           10          11  \
# 0  701.300105 -156.868796  -20.939549  -74.173323   -6.114569 -113.694853
# 1  675.764269  -62.937977    6.805067   81.293412 -118.088808  194.403115
# 2  648.920831 -139.960468  -21.273673  -86.513653  -55.992613 -116.905860
# 3  787.668814   15.156983  -98.600091 -145.574245 -202.840763  -98.928574
# 4  802.254805 -151.235676 -103.875465 -282.741800  -17.221394   44.446209
#
# ...

# %%
#Feature Selection using Random Forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
X = numeric_data.drop(['SalePrice'],axis=1)
y = numeric_data['SalePrice']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
# Out:
# 669     137500
# 1273    177000
# 1309    179200
# 1229    127000
# 658      97500
#          ...
# 776     221500
# 937     253000
# 1454    185000
# 839     130500
# 779     135000
# Name: SalePrice, Length: 438, dtype: int64

# %%
sel = SelectFromModel(RandomForestClassifier(n_estimators = 100))
sel.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier())

# %%
sel.get_support()
# Out:
# array([ True, False,  True,  True, False, False,  True,  True,  True,
#         True, False,  True,  True,  True,  True, False,  True, False,
#        False, False, False, False, False,  True, False,  True, False,
#         True,  True,  True, False, False, False, False, False,  True,
#         True])

# %%
X_train.columns[sel.get_support()]
# Out:
# Index(['Id', 'LotFrontage', 'LotArea', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'GrLivArea', 'TotRmsAbvGrd', 'GarageYrBlt', 'GarageArea',
#        'WoodDeckSF', 'OpenPorchSF', 'MoSold', 'YrSold'],
#       dtype='object')
