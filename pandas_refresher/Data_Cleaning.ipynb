# %%
# modules we'll use
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# read in our data
earthquakes = pd.read_csv("database.csv")

# set seed for reproducibility
np.random.seed(0)

# %%
earthquakes.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# 1                         NaN            NaN                  NaN
# 2                         NaN            NaN                  NaN
# 3                         NaN            NaN                  NaN
# 4                         NaN            NaN                  NaN
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0               NaN               NaN  ISCGEM860706  ISCGEM          ISCGEM
# 1               NaN               NaN  ISCGEM860737  ISCGEM          ISCGEM
# 2               NaN               NaN  ISCGEM860762  ISCGEM          ISCGEM
# 3               NaN               NaN  ISCGEM860856  ISCGEM          ISCGEM
# 4               NaN               NaN  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic
#
# [5 rows x 21 columns]

# %%
inc_values = earthquakes[earthquakes.Date.str.len()>10].Date

# %%
inc_values
# Out:
# 3378     1975-02-23T02:58:41.000Z
# 7512     1985-04-28T02:53:41.530Z
# 20650    2011-03-13T02:23:34.520Z
# Name: Date, dtype: object

# %%
inc_values.str[5:].str[:2]
# Out:
# 3378     02
# 7512     04
# 20650    03
# Name: Date, dtype: object

# %%
inc_values.str[8:].str[:2]
# Out:
# 3378     23
# 7512     28
# 20650    13
# Name: Date, dtype: object

# %%
inc_values = inc_values.str[5:].str[:2] +"/" + inc_values.str[8:].str[:2] + "/" + inc_values.str[:4]

# %%
earthquakes.Date[inc_values.index] = inc_values
# Out:
# C:\Users\akr80\AppData\Local\Temp\ipykernel_20448\1127220996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   earthquakes.Date[inc_values.index] = inc_values

# %%
earthquakes[earthquakes.Date.str.len()>10].Date
# Out:
# 3378     1975-02-23T02:58:41.000Z
# 7512     1985-04-28T02:53:41.530Z
# 20650    2011-03-13T02:23:34.520Z
# Name: Date, dtype: object

# %%
date_value = earthquakes.Date
inc_index = earthquakes.Date.str.len()>10
date_value[inc_index] = inc_values
# Out:
# C:\Users\akr80\AppData\Local\Temp\ipykernel_20448\1531894415.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   date_value[inc_index] = inc_values

# %%
earthquakes.loc[inc_index,'Date'] = inc_values

# %%
inc_values
# Out:
# 3378     02/23/1975
# 7512     04/28/1985
# 20650    03/13/2011
# Name: Date, dtype: object

# %%
earthquakes[inc_index]
# Out:
#              Date                      Time  Latitude  Longitude        Type  \
# 3378   02/23/1975  1975-02-23T02:58:41.000Z     8.017    124.075  Earthquake
# 7512   04/28/1985  1985-04-28T02:53:41.530Z   -32.998    -71.766  Earthquake
# 20650  03/13/2011  2011-03-13T02:23:34.520Z    36.344    142.344  Earthquake
#
#        Depth  Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 3378   623.0          NaN                     NaN        5.6             MB
# 7512    33.0          NaN                     NaN        5.6             MW
# 20650   10.1         13.9                   289.0        5.8            MWC
#
#        ...  Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 3378   ...                         NaN            NaN                  NaN
# 7512   ...                         NaN            NaN                  NaN
# 20650  ...                         NaN           32.3                  NaN
#
#        Horizontal Error  Root Mean Square          ID Source Location Source  \
# 3378                NaN               NaN  USP0000A09     US              US
# 7512                NaN              1.30  USP0002E81     US              US
# 20650               NaN              1.06  USP000HWQP     US              US
#
#       Magnitude Source    Status
# 3378                US  Reviewed
# 7512               HRV  Reviewed
# 20650             GCMT  Reviewed
#
# [3 rows x 21 columns]

# %%
earthquakes.Date = pd.to_datetime(earthquakes.Date,format='%m/%d/%Y')

# %%
earthquakes.dtypes
# Out:
# Date                          datetime64[ns]
# Time                                  object
# Latitude                             float64
# Longitude                            float64
# Type                                  object
# Depth                                float64
# Depth Error                          float64
# Depth Seismic Stations               float64
# Magnitude                            float64
# Magnitude Type                        object
# Magnitude Error                      float64
# Magnitude Seismic Stations           float64
# Azimuthal Gap                        float64
# Horizontal Distance                  float64
# Horizontal Error                     float64
# Root Mean Square                     float64
# ID                                    object
# Source                                object
# Location Source                       object
# Magnitude Source                      object
# Status                                object
# dtype: object

# %%
import pandas as pd
import numpy as np

# helpful modules
import fuzzywuzzy
from fuzzywuzzy import process
import chardet
professors = pd.read_csv("pakistan_intellectual_capital.csv")

# set seed for reproducibility
np.random.seed(0)

# %%
professors.describe(include = 'all')
# Out:
#          Unnamed: 0           S#     Teacher Name  \
# count   1142.000000  1142.000000             1142
# unique          NaN          NaN             1133
# top             NaN          NaN  Muhammad Zubair
# freq            NaN          NaN                3
# mean    1054.350263  1055.350263              NaN
# std      520.202783   520.202783              NaN
# min        2.000000     3.000000              NaN
# 25%      689.250000   690.250000              NaN
# 50%     1087.500000  1088.500000              NaN
# 75%     1476.750000  1477.750000              NaN
# max     1980.000000  1981.000000              NaN
#
#                             University Currently Teaching        Department  \
# count                                                1142              1142
# unique                                                 63                17
# top     Sir Syed University of Engineering and Technology  Computer Science
# freq                                                   81               744
# mean                                                  NaN               NaN
# std                                                   NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN
#
#        Province University Located          Designation Terminal Degree  \
# count                         1142                 1123            1138
# unique                           5                   46              42
# top                         Punjab  Assistant Professor              MS
# freq                           449                  489             463
# mean                           NaN                  NaN             NaN
# std                            NaN                  NaN             NaN
# min                            NaN                  NaN             NaN
# 25%                            NaN                  NaN             NaN
# 50%                            NaN                  NaN             NaN
# 75%                            NaN                  NaN             NaN
# max                            NaN                  NaN             NaN
#
#                                            Graduated from   Country  \
# count                                                1142      1142
# unique                                                350        38
# top     FAST– National University of Computer and Emer...  Pakistan
# freq                                                   67       776
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#                Year Area of Specialization/Research Interests  \
# count    489.000000                                       623
# unique          NaN                                       571
# top             NaN                      Software Engineering
# freq            NaN                                        16
# mean    2010.456033                                       NaN
# std        5.577565                                       NaN
# min     1983.000000                                       NaN
# 25%     2008.000000                                       NaN
# 50%     2012.000000                                       NaN
# 75%     2014.000000                                       NaN
# max     2018.000000                                       NaN
#
#        Other Information
# count                124
# unique                52
# top      PhD in progress
# freq                  27
# mean                 NaN
# std                  NaN
# min                  NaN
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max                  NaN

# %%
professors.Country = professors.Country.str.strip().str.lower()

# %%
str_list = list(professors.Country.unique())

# %%
for i in str_list:
    reduced_list = str_list.copy()
    reduced_list.remove(i)
    matches = fuzzywuzzy.process.extract(i,reduced_list,limit=10,scorer=fuzzywuzzy.fuzz.token_sort_ratio)
    closest_name = ''
    for name,similarity in matches:
        if similarity > 65:
            closest_name = name
            break
    print("Matches for {0} are : {1}".format(i,closest_name))
# Out:
# Matches for thailand are : ireland
# Matches for pakistan are :
# Matches for germany are :
# Matches for austria are : australia
# Matches for australia are : austria
# Matches for uk are :
# Matches for china are :
# Matches for france are :
# Matches for usofa are : usa
# Matches for southkorea are :
# Matches for malaysia are :
# Matches for sweden are :
# Matches for italy are :
# Matches for canada are :
# Matches for norway are :
# Matches for ireland are : finland
# Matches for new zealand are : netherland
# Matches for urbana are :
# Matches for portugal are :
# Matches for russian federation are :
# Matches for usa are : usofa
# Matches for finland are : ireland
# Matches for netherland are : thailand
# Matches for greece are :
# Matches for turkey are :
# Matches for south korea are :
# Matches for macau are :
# Matches for singapore are :
# Matches for spain are :
# Matches for japan are :
# Matches for hongkong are :
# Matches for saudi arabia are :
# Matches for mauritius are :
# Matches for scotland are :

# %%
def fun_match()

# %%
str_list
# Out:
# ['thailand',
#  'pakistan',
#  'germany',
#  'austria',
#  'australia',
#  'uk',
#  'china',
#  'france',
#  'usofa',
#  'southkorea',
#  'malaysia',
#  'sweden',
#  'italy',
#  'canada',
#  'norway',
#  'ireland',
#  'new zealand',
#  'urbana',
#  'portugal',
#  'russian federation',
#  'usa',
#  'finland',
#  'netherland',
#  'greece',
#  'turkey',
#  'south korea',
#  'macau',
#  'singapore',
#  'spain',
#  'japan',
#  'hongkong',
#  'saudi arabia',
#  'mauritius',
#  'scotland']
